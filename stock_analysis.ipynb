# %%
#%%

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import seaborn as sns
import plotly.express as px

# %%
# %%

glob.glob(r'Datasets/*csv')
# Out:
# ['Datasets/XRX_data.csv',
#  'Datasets/GS_data.csv',
#  'Datasets/SPGI_data.csv',
#  'Datasets/MTB_data.csv',
#  'Datasets/V_data.csv',
#  'Datasets/CTAS_data.csv',
#  'Datasets/ESRX_data.csv',
#  'Datasets/APH_data.csv',
#  'Datasets/BBT_data.csv',
#  'Datasets/RHI_data.csv',
#  'Datasets/GGP_data.csv',
#  'Datasets/HCA_data.csv',
#  'Datasets/HD_data.csv',
#  'Datasets/PEP_data.csv',
#  'Datasets/INTC_data.csv',
#  'Datasets/MAC_data.csv',
#  'Datasets/CLX_data.csv',
#  'Datasets/UNP_data.csv',
#  'Datasets/WAT_data.csv',
#  'Datasets/EMN_data.csv',
#  'Datasets/ADSK_data.csv',
#  'Datasets/ALK_data.csv',
#  'Datasets/VZ_data.csv',
#  'Datasets/AFL_data.csv',
#  'Datasets/ADP_data.csv',
#  'Datasets/CSRA_data.csv',
#  'Datasets/AON_data.csv',
#  'Datasets/APC_data.csv',
#  'Datasets/WRK_data.csv',
#  'Datasets/XYL_data.csv',
#  'Datasets/OMC_data.csv',
#  'Datasets/SLB_data.csv',
#  'Datasets/NOV_data.csv',
#  'Datasets/CMA_data.csv',
#  'Datasets/INFO_data.csv',
#  'Datasets/CRM_data.csv',
#  'Datasets/AMGN_data.csv',
#  'Datasets/ED_data.csv',
#  'Datasets/AIZ_data.csv',
#  'Datasets/RSG_data.csv',
#  'Datasets/NRG_data.csv',
#  'Datasets/FLIR_data.csv',
#  'Datasets/JPM_data.csv',
#  'Datasets/HIG_data.csv',
#  'Datasets/REGN_data.csv',
#  'Datasets/UAL_data.csv',
#  'Datasets/AZO_data.csv',
#  'Datasets/STI_data.csv',
#  'Datasets/MHK_data.csv',
#  'Datasets/DFS_data.csv',
#  'Datasets/MU_data.csv',
#  'Datasets/LRCX_data.csv',
#  'Datasets/HRB_data.csv',
#  'Datasets/FOXA_data.csv',
#  'Datasets/ISRG_data.csv',
#  'Datasets/TEL_data.csv',
#  'Datasets/BWA_data.csv',
#  'Datasets/CAG_data.csv',
#  'Datasets/SIG_data.csv',
#  'Datasets/CHD_data.csv',
#  'Datasets/FITB_data.csv',
#  'Datasets/JNPR_data.csv',
#  'Datasets/NFLX_data.csv',
#  'Datasets/IFF_data.csv',
#  'Datasets/EOG_data.csv',
#  'Datasets/NEE_data.csv',
#  'Datasets/SBUX_data.csv',
#  'Datasets/RF_data.csv',
#  'Datasets/CNP_data.csv',
#  'Datasets/COTY_data.csv',
#  'Datasets/MCK_data.csv',
#  'Datasets/HP_data.csv',
#  'Datasets/MOS_data.csv',
#  'Datasets/UA_data.csv',
#  'Datasets/DHI_data.csv',
#  'Datasets/KSU_data.csv',
#  'Datasets/FLR_data.csv',
#  'Datasets/FLS_data.csv',
#  'Datasets/C_data.csv',
#  'Datasets/TPR_data.csv',
#  'Datasets/NTAP_data.csv',
#  'Datasets/DLTR_data.csv',
#  'Datasets/SNA_data.csv',
#  'Datasets/AVGO_data.csv',
#  'Datasets/ROP_data.csv',
#  'Datasets/HOG_data.csv',
#  'Datasets/RL_data.csv',
#  'Datasets/MA_data.csv',
#  'Datasets/MET_data.csv',
#  'Datasets/LNC_data.csv',
#  'Datasets/TAP_data.csv',
#  'Datasets/WEC_data.csv',
#  'Datasets/NAVI_data.csv',
#  'Datasets/GPS_data.csv',
#  'Datasets/EIX_data.csv',
#  'Datasets/BHF_data.csv',
#  'Datasets/GM_data.csv',
#  'Datasets/NOC_data.csv',
#  'Datasets/AVB_data.csv',
#  'Datasets/SRCL_data.csv',
#  'Datasets/EQR_data.csv',
#  'Datasets/ANSS_data.csv',
#  'Datasets/COST_data.csv',
#  'Datasets/CTL_data.csv',
#  'Datasets/AMG_data.csv',
#  'Datasets/PCLN_data.csv',
#  'Datasets/TRIP_data.csv',
#  'Datasets/PSA_data.csv',
#  'Datasets/UTX_data.csv',
#  'Datasets/PGR_data.csv',
#  'Datasets/IVZ_data.csv',
#  'Datasets/GOOG_data.csv',
#  'Datasets/LUK_data.csv',
#  'Datasets/PKG_data.csv',
#  'Datasets/BXP_data.csv',
#  'Datasets/SRE_data.csv',
#  'Datasets/ACN_data.csv',
#  'Datasets/TXT_data(1).csv',
#  'Datasets/QRVO_data.csv',
#  'Datasets/RJF_data.csv',
#  'Datasets/XRAY_data.csv',
#  'Datasets/DWDP_data.csv',
#  'Datasets/CI_data.csv',
#  'Datasets/KSS_data.csv',
#  'Datasets/BHGE_data.csv',
#  'Datasets/ADI_data.csv',
#  'Datasets/JNJ_data.csv',
#  'Datasets/DAL_data.csv',
#  'Datasets/XL_data.csv',
#  'Datasets/CHTR_data.csv',
#  'Datasets/TDG_data.csv',
#  'Datasets/EVHC_data.csv',
#  'Datasets/D_data.csv',
#  'Datasets/ORCL_data.csv',
#  'Datasets/DGX_data.csv',
#  'Datasets/CFG_data.csv',
#  'Datasets/VRSN_data.csv',
#  'Datasets/AJG_data.csv',
#  'Datasets/UNH_data.csv',
#  'Datasets/BIIB_data.csv',
#  'Datasets/DE_data.csv',
#  'Datasets/TXN_data.csv',
#  'Datasets/KR_data.csv',
#  'Datasets/AKAM_data.csv',
#  'Datasets/TWX_data.csv',
#  'Datasets/ETN_data.csv',
#  'Datasets/VLO_data.csv',
#  'Datasets/CINF_data.csv',
#  'Datasets/PRGO_data.csv',
#  'Datasets/PFG_data.csv',
#  'Datasets/STZ_data.csv',
#  'Datasets/AEP_data.csv',
#  'Datasets/BAC_data.csv',
#  'Datasets/PRU_data.csv',
#  'Datasets/LLY_data.csv',
#  'Datasets/NWSA_data.csv',
#  'Datasets/ZBH_data.csv',
#  'Datasets/NI_data.csv',
#  'Datasets/EQT_data.csv',
#  'Datasets/CMCSA_data.csv',
#  'Datasets/TMO_data.csv',
#  'Datasets/O_data.csv',
#  'Datasets/IQV_data.csv',
#  'Datasets/CMS_data.csv',
#  'Datasets/EW_data.csv',
#  'Datasets/COO_data.csv',
#  'Datasets/CPB_data.csv',
#  'Datasets/BDX_data.csv',
#  'Datasets/GLW_data.csv',
#  'Datasets/TIF_data.csv',
#  'Datasets/CTXS_data.csv',
#  'Datasets/MRO_data.csv',
#  'Datasets/OKE_data.csv',
#  'Datasets/MMC_data.csv',
#  'Datasets/SCG_data.csv',
#  'Datasets/LOW_data.csv',
#  'Datasets/PNW_data.csv',
#  'Datasets/VFC_data.csv',
#  'Datasets/CB_data.csv',
#  'Datasets/WMT_data.csv',
#  'Datasets/NFX_data.csv',
#  'Datasets/MTD_data.csv',
#  'Datasets/ADBE_data.csv',
#  'Datasets/COP_data.csv',
#  'Datasets/AIV_data.csv',
#  'Datasets/HES_data.csv',
#  'Datasets/DLR_data.csv',
#  'Datasets/KHC_data.csv',
#  'Datasets/FISV_data.csv',
#  'Datasets/GT_data.csv',
#  'Datasets/VMC_data.csv',
#  'Datasets/SWK_data.csv',
#  'Datasets/ILMN_data.csv',
#  'Datasets/PSX_data.csv',
#  'Datasets/LMT_data.csv',
#  'Datasets/ECL_data.csv',
#  'Datasets/SNPS_data.csv',
#  'Datasets/DUK_data.csv',
#  'Datasets/GIS_data.csv',
#  'Datasets/TSN_data.csv',
#  'Datasets/XEC_data.csv',
#  'Datasets/PH_data.csv',
#  'Datasets/MCHP_data.csv',
#  'Datasets/CNC_data.csv',
#  'Datasets/ANTM_data.csv',
#  'Datasets/IP_data.csv',
#  'Datasets/UAA_data.csv',
#  'Datasets/ANDV_data.csv',
#  'Datasets/CCI_data.csv',
#  'Datasets/CDNS_data.csv',
#  'Datasets/CAT_data.csv',
#  'Datasets/KMX_data.csv',
#  'Datasets/CELG_data.csv',
#  'Datasets/INCY_data.csv',
#  'Datasets/CBOE_data.csv',
#  'Datasets/ALL_data.csv',
#  'Datasets/AMT_data.csv',
#  'Datasets/MDT_data.csv',
#  'Datasets/PNC_data.csv',
#  'Datasets/APD_data.csv',
#  'Datasets/HBAN_data.csv',
#  'Datasets/EBAY_data.csv',
#  'Datasets/BBY_data.csv',
#  'Datasets/ICE_data.csv',
#  'Datasets/WDC_data.csv',
#  'Datasets/EXC_data.csv',
#  'Datasets/TROW_data.csv',
#  'Datasets/ZTS_data.csv',
#  'Datasets/CMG_data.csv',
#  'Datasets/TRV_data.csv',
#  'Datasets/MKC_data.csv',
#  'Datasets/ABC_data.csv',
#  'Datasets/FRT_data.csv',
#  'Datasets/TXN_data(1).csv',
#  'Datasets/DVN_data.csv',
#  'Datasets/VIAB_data.csv',
#  'Datasets/ARNC_data.csv',
#  'Datasets/LLL_data.csv',
#  'Datasets/MNST_data.csv',
#  'Datasets/LEN_data.csv',
#  'Datasets/AEE_data.csv',
#  'Datasets/MSI_data.csv',
#  'Datasets/CSX_data.csv',
#  'Datasets/PVH_data.csv',
#  'Datasets/FL_data.csv',
#  'Datasets/IRM_data.csv',
#  'Datasets/DOV_data.csv',
#  'Datasets/AAL_data.csv',
#  'Datasets/SPG_data.csv',
#  'Datasets/MS_data.csv',
#  'Datasets/CSCO_data.csv',
#  'Datasets/NVDA_data.csv',
#  'Datasets/RRC_data.csv',
#  'Datasets/PKI_data.csv',
#  'Datasets/NSC_data.csv',
#  'Datasets/BEN_data.csv',
#  'Datasets/SBAC_data.csv',
#  'Datasets/UNM_data.csv',
#  'Datasets/VRSK_data.csv',
#  'Datasets/NEM_data.csv',
#  'Datasets/KLAC_data.csv',
#  'Datasets/BLL_data.csv',
#  'Datasets/EMR_data.csv',
#  'Datasets/KMB_data.csv',
#  'Datasets/DIS_data.csv',
#  'Datasets/PPL_data.csv',
#  'Datasets/AET_data.csv',
#  'Datasets/ES_data.csv',
#  'Datasets/UPS_data.csv',
#  'Datasets/EXR_data.csv',
#  'Datasets/ULTA_data.csv',
#  'Datasets/GWW_data.csv',
#  'Datasets/TMK_data.csv',
#  'Datasets/K_data.csv',
#  'Datasets/SNI_data.csv',
#  'Datasets/GRMN_data.csv',
#  'Datasets/CVS_data.csv',
#  'Datasets/CF_data.csv',
#  'Datasets/AMD_data.csv',
#  'Datasets/PNR_data.csv',
#  'Datasets/RHT_data.csv',
#  'Datasets/AME_data.csv',
#  'Datasets/APTV_data.csv',
#  'Datasets/CTSH_data.csv',
#  'Datasets/MRK_data.csv',
#  'Datasets/WU_data.csv',
#  'Datasets/IBM_data.csv',
#  'Datasets/MSFT_data.csv',
#  'Datasets/STT_data.csv',
#  'Datasets/FMC_data.csv',
#  'Datasets/UHS_data.csv',
#  'Datasets/PPG_data.csv',
#  'Datasets/KMI_data.csv',
#  'Datasets/RE_data.csv',
#  'Datasets/HON_data.csv',
#  'Datasets/PX_data.csv',
#  'Datasets/AAPL_data.csv',
#  'Datasets/RMD_data.csv',
#  'Datasets/MAT_data.csv',
#  'Datasets/PEG_data.csv',
#  'Datasets/INTU_data.csv',
#  'Datasets/SHW_data.csv',
#  'Datasets/KEY_data.csv',
#  'Datasets/ADM_data.csv',
#  'Datasets/MMM_data.csv',
#  'Datasets/AOS_data.csv',
#  'Datasets/CVX_data.csv',
#  'Datasets/PLD_data.csv',
#  'Datasets/CL_data.csv',
#  'Datasets/DISH_data.csv',
#  'Datasets/A_data.csv',
#  'Datasets/EQIX_data.csv',
#  'Datasets/GE_data.csv',
#  'Datasets/GD_data.csv',
#  'Datasets/ALLE_data.csv',
#  'Datasets/PHM_data.csv',
#  'Datasets/AIG_data.csv',
#  'Datasets/LKQ_data.csv',
#  'Datasets/HSIC_data.csv',
#  'Datasets/ADS_data.csv',
#  'Datasets/VRTX_data.csv',
#  'Datasets/MDLZ_data.csv',
#  'Datasets/MON_data.csv',
#  'Datasets/MPC_data.csv',
#  'Datasets/APA_data.csv',
#  'Datasets/BRK.B_data.csv',
#  'Datasets/AMP_data.csv',
#  'Datasets/FCX_data.csv',
#  'Datasets/PCAR_data.csv',
#  'Datasets/NLSN_data.csv',
#  'Datasets/TJX_data.csv',
#  'Datasets/PYPL_data.csv',
#  'Datasets/FBHS_data.csv',
#  'Datasets/AXP_data.csv',
#  'Datasets/BA_data.csv',
#  'Datasets/LNT_data.csv',
#  'Datasets/ALB_data.csv',
#  'Datasets/PG_data.csv',
#  'Datasets/XEL_data.csv',
#  'Datasets/ATVI_data.csv',
#  'Datasets/FFIV_data.csv',
#  'Datasets/EFX_data.csv',
#  'Datasets/CMI_data.csv',
#  'Datasets/EL_data.csv',
#  'Datasets/ESS_data.csv',
#  'Datasets/PCG_data.csv',
#  'Datasets/ALGN_data.csv',
#  'Datasets/KORS_data.csv',
#  'Datasets/HSY_data.csv',
#  'Datasets/HLT_data.csv',
#  'Datasets/T_data.csv',
#  'Datasets/CHRW_data.csv',
#  'Datasets/AYI_data.csv',
#  'Datasets/LYB_data.csv',
#  'Datasets/HUM_data.csv',
#  'Datasets/FB_data.csv',
#  'Datasets/DRI_data.csv',
#  'Datasets/SYK_data.csv',
#  'Datasets/MAA_data.csv',
#  'Datasets/SCHW_data.csv',
#  'Datasets/USB_data.csv',
#  'Datasets/TXT_data.csv',
#  'Datasets/PM_data.csv',
#  'Datasets/NTRS_data.csv',
#  'Datasets/BAX_data.csv',
#  'Datasets/ITW_data.csv',
#  'Datasets/BK_data.csv',
#  'Datasets/DVA_data.csv',
#  'Datasets/GPN_data.csv',
#  'Datasets/IT_data.csv',
#  'Datasets/CCL_data.csv',
#  'Datasets/SWKS_data.csv',
#  'Datasets/HAS_data.csv',
#  'Datasets/DHR_data.csv',
#  'Datasets/WMB_data.csv',
#  'Datasets/HCN_data.csv',
#  'Datasets/CBS_data.csv',
#  'Datasets/EA_data.csv',
#  'Datasets/CME_data.csv',
#  'Datasets/SEE_data.csv',
#  'Datasets/VTR_data.csv',
#  'Datasets/HST_data.csv',
#  'Datasets/SLG_data.csv',
#  'Datasets/JWN_data.csv',
#  'Datasets/LB_data.csv',
#  'Datasets/SO_data.csv',
#  'Datasets/UDR_data.csv',
#  'Datasets/ALXN_data.csv',
#  'Datasets/NUE_data.csv',
#  'Datasets/GPC_data.csv',
#  'Datasets/FDX_data.csv',
#  'Datasets/SYF_data.csv',
#  'Datasets/LUV_data.csv',
#  'Datasets/TGT_data.csv',
#  'Datasets/VAR_data.csv',
#  'Datasets/DISCA_data.csv',
#  'Datasets/FIS_data.csv',
#  'Datasets/EXPE_data.csv',
#  'Datasets/EXPD_data.csv',
#  'Datasets/DRE_data.csv',
#  'Datasets/LH_data.csv',
#  'Datasets/DXC_data.csv',
#  'Datasets/REG_data.csv',
#  'Datasets/PWR_data.csv',
#  'Datasets/WLTW_data.csv',
#  'Datasets/XOM_data.csv',
#  'Datasets/IDXX_data.csv',
#  'Datasets/AVY_data.csv',
#  'Datasets/BF.B_data.csv',
#  'Datasets/PXD_data.csv',
#  'Datasets/WM_data.csv',
#  'Datasets/AMAT_data.csv',
#  'Datasets/JEC_data.csv',
#  'Datasets/MYL_data.csv',
#  'Datasets/ROST_data.csv',
#  'Datasets/GOOGL_data.csv',
#  'Datasets/BSX_data.csv',
#  'Datasets/CXO_data.csv',
#  'Datasets/HPQ_data.csv',
#  'Datasets/WYNN_data.csv',
#  'Datasets/PDCO_data.csv',
#  'Datasets/HRL_data.csv',
#  'Datasets/ROK_data.csv',
#  'Datasets/FE_data.csv',
#  'Datasets/WHR_data.csv',
#  'Datasets/ETFC_data.csv',
#  'Datasets/FTI_data.csv',
#  'Datasets/AWK_data.csv',
#  'Datasets/NDAQ_data.csv',
#  'Datasets/DPS_data.csv',
#  'Datasets/DISCK_data.csv',
#  'Datasets/ETR_data.csv',
#  'Datasets/VNO_data.csv',
#  'Datasets/XLNX_data.csv',
#  'Datasets/HII_data.csv',
#  'Datasets/KO_data.csv',
#  'Datasets/LEG_data.csv',
#  'Datasets/IR_data.csv',
#  'Datasets/MLM_data.csv',
#  'Datasets/TSCO_data.csv',
#  'Datasets/NWS_data.csv',
#  'Datasets/RTN_data.csv',
#  'Datasets/TSS_data.csv',
#  'Datasets/HRS_data.csv',
#  'Datasets/BLK_data.csv',
#  'Datasets/GILD_data.csv',
#  'Datasets/PAYX_data.csv',
#  'Datasets/DG_data.csv',
#  'Datasets/MCD_data.csv',
#  'Datasets/FTV_data.csv',
#  'Datasets/IPG_data.csv',
#  'Datasets/KIM_data.csv',
#  'Datasets/STX_data.csv',
#  'Datasets/AES_data.csv',
#  'Datasets/PFE_data.csv',
#  'Datasets/YUM_data.csv',
#  'Datasets/CAH_data.csv',
#  'Datasets/AGN_data.csv',
#  'Datasets/MGM_data.csv',
#  'Datasets/CHK_data.csv',
#  'Datasets/HBI_data.csv',
#  'Datasets/DTE_data.csv',
#  'Datasets/NWL_data.csv',
#  'Datasets/M_data.csv',
#  'Datasets/L_data.csv',
#  'Datasets/ABT_data.csv',
#  'Datasets/WBA_data.csv',
#  'Datasets/BMY_data.csv',
#  'Datasets/HOLX_data.csv',
#  'Datasets/PBCT_data.csv',
#  'Datasets/URI_data.csv',
#  'Datasets/COL_data.csv',
#  'Datasets/AMZN_data.csv',
#  'Datasets/JCI_data.csv',
#  'Datasets/CBG_data.csv',
#  'Datasets/NCLH_data.csv',
#  'Datasets/RCL_data.csv',
#  'Datasets/NBL_data.csv',
#  'Datasets/SYMC_data.csv',
#  'Datasets/CA_data.csv',
#  'Datasets/JBHT_data.csv',
#  'Datasets/FOX_data.csv',
#  'Datasets/FAST_data.csv',
#  'Datasets/ZION_data.csv',
#  'Datasets/ABBV_data.csv',
#  'Datasets/MCO_data.csv',
#  'Datasets/SYY_data.csv',
#  'Datasets/MAS_data.csv',
#  'Datasets/OXY_data.csv',
#  'Datasets/MAR_data.csv',
#  'Datasets/AAP_data.csv',
#  'Datasets/HPE_data.csv',
#  'Datasets/MO_data.csv',
#  'Datasets/ARE_data.csv',
#  'Datasets/ORLY_data.csv',
#  'Datasets/HCP_data.csv',
#  'Datasets/T_data(1).csv',
#  'Datasets/NKE_data.csv',
#  'Datasets/HAL_data.csv',
#  'Datasets/CERN_data.csv',
#  'Datasets/SJM_data.csv',
#  'Datasets/WY_data.csv',
#  'Datasets/WYN_data.csv',
#  'Datasets/WFC_data.csv',
#  'Datasets/QCOM_data.csv',
#  'Datasets/TWX_data(1).csv',
#  'Datasets/COF_data.csv',
#  'Datasets/COG_data.csv',
#  'Datasets/F_data.csv']

# %%
# %%

# Counts the number of files with .csv
len(glob.glob(r'Datasets/*csv'))
# Out:
# 509

# %%
#%%

import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# %%

company_list=[
    'Datasets/AAPL_data.csv',
    'Datasets/AMZN_data.csv',
    'Datasets/GOOGL_data.csv',
    'Datasets/MSFT_data.csv'

]

# %%
# %%

company_list
# Out:
# ['Datasets/AAPL_data.csv',
#  'Datasets/AMZN_data.csv',
#  'Datasets/GOOGL_data.csv',
#  'Datasets/MSFT_data.csv']

# %%
# %%

all_data = pd.DataFrame()

for file in company_list:
    
    current_df = pd.read_csv(file)

    all_data=pd.concat([all_data,current_df],ignore_index=True)

# %%
# %%

all_data['Name'].unique()
# Out:
# array(['AAPL', 'AMZN', 'GOOGL', 'MSFT'], dtype=object)

# %%
 # %%

 #checking for the null values
all_data.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
# %%

#checking for the datatypes
all_data.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
# %%

#converting date datatype to datetime
all_data['date']=pd.to_datetime(all_data['date'])

# %%
# %%

tech_list=all_data['Name'].unique()

# %%
# %%

# Creating trend chart for all the companies Apple,Amazon,Google,Microsoft
plt.figure(figsize=(20,12))

for index , company in enumerate(tech_list , 1):
    plt.subplot(2 , 2 , index) ## creating subplot for each stock
    filter1 = all_data['Name']==company
    df = all_data[filter1]
    plt.plot(df['date'] , df['close']) ## plotting "date" vs "close"
    plt.title(company)

# %%
# %%

all_data['close'].rolling(window=10)
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
# %%

new_data=all_data

# %%
# %%

new_data
# Out:
#            date     open     high      low    close     volume  Name
# 0    2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1    2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2    2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3    2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4    2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
# ...         ...      ...      ...      ...      ...        ...   ...
# 5031 2018-02-01  94.7900  96.0700  93.5813  94.2600   47227882  MSFT
# 5032 2018-02-02  93.6400  93.9700  91.5000  91.7800   47867753  MSFT
# 5033 2018-02-05  90.5600  93.2400  88.0000  88.0000   51031465  MSFT
# 5034 2018-02-06  86.8900  91.4750  85.2500  91.3300   67998564  MSFT
# 5035 2018-02-07  90.4900  91.7700  89.2000  89.6100   41107592  MSFT
#
# [5036 rows x 7 columns]

# %%
# %%

ma_value=[10,20,30]

for ma in ma_value:
    new_data["close_" + str(ma)]=new_data['close'].rolling(ma).mean()

# %%
# %%

new_data.head(50)
# Out:
#          date     open     high      low    close     volume  Name  close_10  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL       NaN
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL       NaN
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL       NaN
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL       NaN
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL       NaN
# 5  2013-02-15  66.9785  67.1656  65.7028  65.7371   97924631  AAPL       NaN
# 6  2013-02-19  65.8714  66.1042  64.8356  65.7128  108854046  AAPL       NaN
# 7  2013-02-20  65.3842  65.3842  64.1142  64.1214  118891367  AAPL       NaN
# 8  2013-02-21  63.7142  64.1671  63.2599  63.7228  111596821  AAPL       NaN
# 9  2013-02-22  64.1785  64.5142  63.7999  64.4014   82583823  AAPL  66.03251
# 10 2013-02-25  64.8356  65.0171  63.2242  63.2571   92899597  AAPL  65.57280
# 11 2013-02-26  63.4028  64.5056  62.5228  64.1385  125096657  AAPL  65.13051
# 12 2013-02-27  64.0614  64.6342  62.9499  63.5099  146674682  AAPL  64.79722
# 13 2013-02-28  63.4357  63.9814  63.0571  63.0571   80532382  AAPL  64.43137
# 14 2013-03-01  62.5714  62.5971  61.4257  61.4957  137899041  AAPL  63.91538
# 15 2013-03-04  61.1142  61.1714  59.8571  60.0071  145406366  AAPL  63.34238
# 16 2013-03-05  60.2114  62.1699  60.1071  61.5919  159298020  AAPL  62.93029
# 17 2013-03-06  62.0728  62.1785  60.6328  60.8088  114903180  AAPL  62.59903
# 18 2013-03-07  60.6428  61.7157  60.1514  61.5117  116992841  AAPL  62.37792
# 19 2013-03-08  61.3999  62.2042  61.2299  61.6742   97854442  AAPL  62.10520
# 20 2013-03-11  61.3928  62.7157  60.7342  62.5528  118272126  AAPL  62.03477
# 21 2013-03-12  62.2285  62.6971  61.0814  61.2042  116268341  AAPL  61.74134
# 22 2013-03-13  61.2071  62.0714  60.7657  61.1928  101369051  AAPL  61.50963
# 23 2013-03-14  61.8328  62.0914  61.4928  61.7857   75834906  AAPL  61.38249
# 24 2013-03-15  62.5614  63.4614  62.4642  63.3799  160710606  AAPL  61.57091
# 25 2013-03-18  63.0642  65.3514  63.0285  65.1028  150441144  AAPL  62.08048
# 26 2013-03-19  65.6428  65.8528  64.0714  64.9271  131531708  AAPL  62.41400
# 27 2013-03-20  65.3456  65.3756  64.2271  64.5828   77016849  AAPL  62.79140
# 28 2013-03-21  64.3171  65.4256  64.2999  64.6756   95493524  AAPL  63.10779
# 29 2013-03-22  64.9399  66.0142  64.7299  65.9871   98570591  AAPL  63.53908
# 30 2013-03-25  66.3842  67.1356  65.9685  66.2256  125073165  AAPL  63.90636
# 31 2013-03-26  66.4914  66.5485  65.7899  65.8765   73428208  AAPL  64.37359
# 32 2013-03-27  65.2085  65.2571  64.3899  64.5828   81854409  AAPL  64.71259
# 33 2013-03-28  64.2599  64.5455  63.0885  63.2371  110698007  AAPL  64.85773
# 34 2013-04-01  63.1285  63.3854  61.1057  61.2728   97294421  AAPL  64.64702
# 35 2013-04-02  61.0857  62.5914  60.9142  61.3988  132350022  AAPL  64.27662
# 36 2013-04-03  61.6242  62.4685  61.4728  61.7128   90719482  AAPL  63.95519
# 37 2013-04-04  61.9657  62.1428  60.7499  61.1028   89589332  AAPL  63.60719
# 38 2013-04-05  60.6428  60.7071  59.9542  60.4571   95743088  AAPL  63.18534
# 39 2013-04-08  60.6928  61.0714  60.3557  60.8871   75169647  AAPL  62.67534
# 40 2013-04-09  60.9085  61.2142  60.3928  60.9971   76615504  AAPL  62.15249
# 41 2013-04-10  61.1571  62.4371  60.8585  62.2414   93895844  AAPL  61.78898
# 42 2013-04-11  61.9599  62.5699  61.5999  62.0471   82073628  AAPL  61.53541
# 43 2013-04-12  62.0214  62.0214  61.2985  61.3999   59651011  AAPL  61.35169
# 44 2013-04-15  60.9999  61.1271  59.9357  59.9785   79157071  AAPL  61.22226
# 45 2013-04-16  60.2242  60.9442  60.0814  60.8914   76222076  AAPL  61.17152
# 46 2013-04-17  60.0385  60.0857  56.8728  57.5428  236138966  AAPL  60.75452
# 47 2013-04-18  57.8557  57.9699  55.6774  56.0071  166438048  AAPL  60.24495
# 48 2013-04-19  55.4242  57.0857  55.0142  55.7899  152194413  AAPL  59.77823
# 49 2013-04-22  56.0914  57.4571  55.8964  56.9528  107338322  AAPL  59.38480
#
#      close_20   close_30
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
# 5         NaN        NaN
# 6         NaN        NaN
# 7         NaN        NaN
# 8         NaN        NaN
# 9         NaN        NaN
# 10        NaN        NaN
# 11        NaN        NaN
# 12        NaN        NaN
# 13        NaN        NaN
# 14        NaN        NaN
# 15        NaN        NaN
# 16        NaN        NaN
# 17        NaN        NaN
# 18        NaN        NaN
# 19  64.068855        NaN
# 20  63.803785        NaN
# 21  63.435925        NaN
# 22  63.153425        NaN
# 23  62.906930        NaN
# 24  62.743145        NaN
# 25  62.711430        NaN
# 26  62.672145        NaN
# 27  62.695215        NaN
# 28  62.742855        NaN
# 29  62.822140  63.892263
# 30  62.970565  63.837977
# 31  63.057465  63.748480
# 32  63.111110  63.673147
# 33  63.120110  63.557197
# 34  63.108965  63.377770
# 35  63.178550  63.233160
# 36  63.184595  63.099827
# 37  63.199295  62.999207
# 38  63.146565  62.890350
# 39  63.107210  62.773207
# 40  63.029425  62.697873
# 41  63.081285  62.634637
# 42  63.124000  62.585877
# 43  63.104710  62.530637
# 44  62.934640  62.480063
# 45  62.724070  62.509540
# 46  62.354855  62.374570
# 47  61.926070  62.214513
# 48  61.481785  62.023787
# 49  61.030070  61.866407

# %%
# %%

#Lets plot a graph using pandas library
new_data.set_index('date')
# Out:
#                open     high      low    close     volume  Name  close_10  \
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL       NaN
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL       NaN
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL       NaN
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL       NaN
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL       NaN
# ...             ...      ...      ...      ...        ...   ...       ...
# 2018-02-01  94.7900  96.0700  93.5813  94.2600   47227882  MSFT    92.765
# 2018-02-02  93.6400  93.9700  91.5000  91.7800   47867753  MSFT    92.943
# 2018-02-05  90.5600  93.2400  88.0000  88.0000   51031465  MSFT    92.582
# 2018-02-06  86.8900  91.4750  85.2500  91.3300   67998564  MSFT    92.525
# 2018-02-07  90.4900  91.7700  89.2000  89.6100   41107592  MSFT    92.304
#
#             close_20   close_30
# date
# 2013-02-08       NaN        NaN
# 2013-02-11       NaN        NaN
# 2013-02-12       NaN        NaN
# 2013-02-13       NaN        NaN
# 2013-02-14       NaN        NaN
# ...              ...        ...
# 2018-02-01   90.6770  89.019000
# 2018-02-02   90.9105  89.217333
# 2018-02-05   90.9010  89.300000
# 2018-02-06   91.0535  89.494333
# 2018-02-07   91.1230  89.631000
#
# [5036 rows x 9 columns]

# %%
# %%

plt.figure(figsize=(20,12))

for index , company in enumerate(tech_list , 1):
    plt.subplot(2 , 2 , index) ## creating subplot for each stock
    filter1 = new_data['Name']==company
    df = new_data[filter1]
    df[['close_10','close_20', 'close_30']].plot(ax=plt.gca())
    plt.title(company)

# %%
  #%%

new_data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name', 'close_10',
#        'close_20', 'close_30'],
#       dtype='object')

# %%
# %%

apple=pd.read_csv("Datasets/AAPL_data.csv")

# %%
#%%

apple['Daily return(in %)'] = apple['close'].pct_change() * 100

### pct_change() returns : Percentage change between the current and a prior element.

# %%
# %%

apple.dtypes
# Out:
# date                   object
# open                  float64
# high                  float64
# low                   float64
# close                 float64
# volume                  int64
# Name                   object
# Daily return(in %)    float64
# dtype: object

# %%
# %%

#Since the date object is not it in proper datatype we will convert it to datetime
apple['date'] =pd.to_datetime(apple['date'])

# %%
# %%

apple.dtypes
# Out:
# date                  datetime64[ns]
# open                         float64
# high                         float64
# low                          float64
# close                        float64
# volume                         int64
# Name                          object
# Daily return(in %)           float64
# dtype: object

# %%
# %%

apple.set_index('date' , inplace=True)

# %%
# %%

apple['close'].resample('M').mean() ## resample data on monthly basis ..
# Out:
# date
# 2013-02-28     65.306264
# 2013-03-31     63.120110
# 2013-04-30     59.966432
# 2013-05-31     63.778927
# 2013-06-30     60.791120
#                  ...
# 2017-10-31    157.817273
# 2017-11-30    172.406190
# 2017-12-31    171.891500
# 2018-01-31    174.005238
# 2018-02-28    161.468000
# Freq: ME, Name: close, Length: 61, dtype: float64

# %%
# %%

apple['close'].resample('M').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
# %%

apple['close'].resample('Y').mean() ## resample data on Yearly basis ..
# Out:
# date
# 2013-12-31     67.237839
# 2014-12-31     92.264531
# 2015-12-31    120.039861
# 2016-12-31    104.604008
# 2017-12-31    150.585080
# 2018-12-31    171.594231
# Freq: YE-DEC, Name: close, dtype: float64

# %%
# %%

apple['close'].resample('Y').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
# %%

app = pd.read_csv(company_list[0])
amzn = pd.read_csv(company_list[1])
google = pd.read_csv(company_list[2])
msft = pd.read_csv(company_list[3])

# %%
# %%

closing_price = pd.DataFrame()

# %%
# %%

closing_price['apple_close'] = app['close']
closing_price['amzn_close'] = amzn['close']
closing_price['goog_close'] = google['close']
closing_price['msft_close'] = msft['close']

# %%
# %%

sns.pairplot(closing_price)

# %%
# %%

closing_price.corr()
# Out:
#              apple_close  amzn_close  goog_close  msft_close
# apple_close     1.000000    0.819078    0.843736    0.899689
# amzn_close      0.819078    1.000000    0.973988    0.955977
# goog_close      0.843736    0.973988    1.000000    0.970779
# msft_close      0.899689    0.955977    0.970779    1.000000

# %%
# %%

sns.heatmap(closing_price.corr() , annot=True)
# Out:
# <Axes: >

# %%
# %%

closing_price
# Out:
#       apple_close  amzn_close  goog_close  msft_close
# 0         67.8542      261.95    393.0777       27.55
# 1         68.5614      257.21    391.6012       27.86
# 2         66.8428      258.70    390.7403       27.88
# 3         66.7156      269.47    391.8214       28.03
# 4         66.6556      269.24    394.3039       28.04
# ...           ...         ...         ...         ...
# 1254     167.7800     1390.00   1181.5900       94.26
# 1255     160.5000     1429.95   1119.2000       91.78
# 1256     156.4900     1390.00   1062.3900       88.00
# 1257     163.0300     1442.84   1084.4300       91.33
# 1258     159.5400     1416.78   1055.4100       89.61
#
# [1259 rows x 4 columns]

# %%
# %%

closing_price['apple_close'].shift(1)
# Out:
# 0            NaN
# 1        67.8542
# 2        68.5614
# 3        66.8428
# 4        66.7156
#           ...
# 1254    167.4300
# 1255    167.7800
# 1256    160.5000
# 1257    156.4900
# 1258    163.0300
# Name: apple_close, Length: 1259, dtype: float64

# %%
# %%

(closing_price['apple_close'] - closing_price['apple_close'].shift(1))/closing_price['apple_close'].shift(1) * 100
# Out:
# 0            NaN
# 1       1.042235
# 2      -2.506658
# 3      -0.190297
# 4      -0.089934
#           ...
# 1254    0.209043
# 1255   -4.339015
# 1256   -2.498442
# 1257    4.179181
# 1258   -2.140710
# Name: apple_close, Length: 1259, dtype: float64

# %%
# %%

for col in closing_price.columns:
    closing_price[col + '_pct_change'] = (closing_price[col] - closing_price[col].shift(1))/closing_price[col].shift(1) * 100

# %%
# %%

closing_price.columns
# Out:
# Index(['apple_close', 'amzn_close', 'goog_close', 'msft_close',
#        'apple_close_pct_change', 'amzn_close_pct_change',
#        'goog_close_pct_change', 'msft_close_pct_change'],
#       dtype='object')

# %%
# %%

clsing_p = closing_price[['apple_close_pct_change', 'amzn_close_pct_change',
       'goog_close_pct_change', 'msft_close_pct_change']]

# %%
# %%

clsing_p
# Out:
#       apple_close_pct_change  amzn_close_pct_change  goog_close_pct_change  \
# 0                        NaN                    NaN                    NaN
# 1                   1.042235              -1.809506              -0.375625
# 2                  -2.506658               0.579293              -0.219841
# 3                  -0.190297               4.163123               0.276680
# 4                  -0.089934              -0.085353               0.633579
# ...                      ...                    ...                    ...
# 1254                0.209043              -4.196734              -0.053290
# 1255               -4.339015               2.874101              -5.280173
# 1256               -2.498442              -2.793804              -5.075947
# 1257                4.179181               3.801439               2.074568
# 1258               -2.140710              -1.806160              -2.676060
#
#       msft_close_pct_change
# 0                       NaN
# 1                  1.125227
# 2                  0.071788
# 3                  0.538020
# 4                  0.035676
# ...                     ...
# 1254              -0.789391
# 1255              -2.631021
# 1256              -4.118544
# 1257               3.784091
# 1258              -1.883280
#
# [1259 rows x 4 columns]

# %%
# %%

g = sns.PairGrid(data= clsing_p)
g.map_diag(sns.histplot)
g.map_lower(sns.scatterplot)
g.map_upper(sns.kdeplot)

# %%
# %%

clsing_p.corr()
# Out:
#                         apple_close_pct_change  amzn_close_pct_change  \
# apple_close_pct_change                1.000000               0.287659
# amzn_close_pct_change                 0.287659               1.000000
# goog_close_pct_change                 0.348858               0.548423
# msft_close_pct_change                 0.366598               0.402678
#
#                         goog_close_pct_change  msft_close_pct_change
# apple_close_pct_change               0.348858               0.366598
# amzn_close_pct_change                0.548423               0.402678
# goog_close_pct_change                1.000000               0.488373
# msft_close_pct_change                0.488373               1.000000
